# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exploratory Data Analysis (EDA) - Bar Chart 10 Most Flight
df = pd.read_csv("airlines_flights_data.csv")

# Bar Chart
plt.figure(figsize=(10, 6))
ax = top_context.plot(kind='bar')
# Add label
for i, value in enumerate(top_context):
    plt.text(i, value + 1, str(value), ha='center', va='bottom')
plt.title(f"10 Most Flight")
plt.xlabel(title)
plt.ylabel("Number of Schedule")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Exploratory Data Analysis (EDA) - Bar Chart 10 Most Flight Duration (Round Up)
df = pd.read_csv("airlines_flights_data.csv")

# Group by Duration (Ceil)
duration_summary = (
    df.assign(duration_hour=np.ceil(df['duration']))   
      .groupby('duration_hour')
      .size()
      .reset_index(name='total_flight')
      .sort_values(by='total_flight', ascending=False)
      .head(10)
)

# Bar Chart
plt.figure(figsize=(10, 6))
ax = duration_summary.plot(
    x='duration_hour',
    y='total_flight',
    kind='bar',
    legend=False
)
# Add label
for i, value in enumerate(duration_summary['total_flight']):
    plt.text(i, value + 1, str(value), ha='center', va='bottom')
plt.title("10 Most Flight Duration (Round Up)")
plt.xlabel("Duration Hour")
plt.ylabel("Number of Flights")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Exploratory Data Analysis (EDA) - Bar Chart 10 Most Price Range (Round Up to 100)
df = pd.read_csv("airlines_flights_data.csv")

# Group by Price Range 
price_summary = (
    df.assign(price_range=np.ceil(df['price'] / 100) * 100)  
      .groupby('price_range')
      .size()
      .reset_index(name='total_flight')
      .sort_values(by='total_flight', ascending=False)
      .head(10)
)

# Bar Chart
plt.figure(figsize=(10, 6))
ax = price_summary.plot(
    x='price_range',
    y='total_flight',
    kind='bar',
    legend=False
)
# Add label
for i, value in enumerate(price_summary['total_flight']):
    plt.text(i, value + 1, str(value), ha='center', va='bottom')
plt.title("10 Most Price Range (Round Up to 100)")
plt.xlabel("Price Range")
plt.ylabel("Number of Flights")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
